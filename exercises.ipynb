# %%
import pandas as pd
import typing as t

# %%
shapes = pd.read_csv("shapes.csv", index_col=0)
banking = pd.read_csv("banking.csv", index_col=0)
#banking.columns = [c.strip() for c in banking.columns]

# %%
banking
# Out:
#               Country    BankType    Owner      Code  CorpC  FinLib  RegInt  \
# Case
# ABNAmro           NLD   Universal   Public        No   0.74    0.98     144
# Barclays          GBR  Commercial   Public  Explicit   0.14    1.00     277
# BNP Paribas       FRA   Universal   Public  Implicit   0.82    1.00      75
# Carnegie          SWE  Investment   Public        No   0.71    0.95      83
# Citigroup         USA  Commercial   Public  Explicit   0.00    1.00     426
# Coutts \& Co      GBR     Private   Public  Implicit   0.14    1.00     277
# CS                CHE   Universal   Public  Explicit   0.44    0.95      83
# Deutsche Bank     GER   Universal   Public  Explicit   0.95    0.90      45
# Goldman Sachs     USA  Investment   Public  Explicit   0.00    1.00     426
# HSBC              GBR  Commercial   Public  Implicit   0.14    1.00     277
# ING               NLD   Universal   Public  Implicit   0.74    0.98     144
# JPMorgan          USA  Commercial   Public  Explicit   0.00    1.00     426
# Julius Baer       CHE     Private   Public        No   0.44    0.95      83
# LCF               FRA     Private  Private        No   0.82    1.00      75
# LODH              CHE     Private  Private        No   0.44    0.95      83
# MeesPierson       NLD     Private   Public        No   0.74    0.98     144
# Merrill Lynch     USA  Investment   Public  Implicit   0.00    1.00     426
# Morgan S          USA  Investment   Public  Explicit   0.14    1.00     277
# Nordea            SWE   Universal   Public  Implicit   0.71    0.95      83
# Pictet & Cie      CHE     Private  Private        No   0.44    0.95      83
# RBC               CAN   Universal   Public  Explicit   0.23    1.00     149
# Rothschild        GBR  Investment  Private        No   0.14    1.00     277
# Santander         ESP   Universal   Public  Explicit   0.77    1.00      53
# SG                FRA   Universal   Public  Explicit   0.82    1.00      75
# UBP               CHE     Private  Private        No   0.44    0.95      83
# UBS               CHE   Universal   Public  Explicit   0.44    0.95      83
#
#               BList Wolfs
# Case
# ABNAmro         Yes    No
# Barclays        Yes   Yes
# BNP Paribas      No    No
# Carnegie         No    No
# Citigroup       Yes   Yes
# Coutts \& Co    Yes    No
# CS              Yes   Yes
# Deutsche Bank    No   Yes
# Goldman Sachs   Yes   Yes
# HSBC            Yes   Yes
# ING             Yes    No
# JPMorgan        Yes   Yes
# Julius Baer     Yes    No
# LCF              No    No
# LODH            Yes    No
# MeesPierson     Yes    No
# Merrill Lynch   Yes    No
# Morgan S        Yes    No
# Nordea           No    No
# Pictet & Cie    Yes    No
# RBC              No    No
# Rothschild      Yes    No
# Santander        No   Yes
# SG               No   Yes
# UBP             Yes    No
# UBS             Yes   Yes

# %% [markdown]
# # Scaling

# %%
def scaling_nominal(df: pd.DataFrame, column: str):
    # get all the unique values for the column
    uniques = df[column].unique()

    # copy the dataframe without the column we are replacing
    df_scaled = df[[c for c in df.columns if c!= column]].copy()

    for unique in uniques:
        df_scaled[f"{column}={unique}"] = df[column] == unique

    return df_scaled

# %%
def scaling_ordinal(df: pd.DataFrame, column: str, order_list: t.List=None):
    # get all the unique values for the column
    uniques = df[column].unique()

    # copy the dataframe without the column we are replacing
    df_scaled = df[[c for c in df.columns if c!= column]].copy()

    for unique in uniques:
        if order_list:
            df_scaled[f"{column}<={unique}"] = df[column].apply(order_list.index) <= order_list.index(unique)
        else:
            df_scaled[f"{column}<={unique}"] = df[column] <= unique

    return df_scaled

# %%
def scaling_interordinal(df: pd.DataFrame, column: str, order_list=None):
    # get all the unique values for the column
    uniques = df[column].unique()

    # copy the dataframe without the column we are replacing
    df_scaled = df[[c for c in df.columns if c!= column]].copy()

    for unique in uniques:
        if order_list:
            df_scaled[f"{column}<={unique}"] = df[column].apply(order_list.index) <= order_list.index(unique)
            df_scaled[f"{column}>={unique}"] = df[column].apply(order_list.index) >= order_list.index(unique)
        else:
            df_scaled[f"{column}<={unique}"] = df[column] <= unique
            df_scaled[f"{column}>={unique}"] = df[column] >= unique

    return df_scaled

# %%
scaling_nominal(banking, "Country")
# Out:
#                   BankType     Owner       Code  CorpC  FinLib  RegInt BList  \
# Case
# ABNAmro          Universal    Public         No   0.74    0.98     144   Yes
# Barclays        Commercial    Public   Explicit   0.14    1.00     277   Yes
# BNP Paribas      Universal    Public   Implicit   0.82    1.00      75    No
# Carnegie        Investment    Public         No   0.71    0.95      83    No
# Citigroup       Commercial    Public   Explicit   0.00    1.00     426   Yes
# Coutts \& Co       Private    Public   Implicit   0.14    1.00     277   Yes
# CS               Universal    Public   Explicit   0.44    0.95      83   Yes
# Deutsche Bank    Universal    Public   Explicit   0.95    0.90      45    No
# Goldman Sachs   Investment    Public   Explicit   0.00    1.00     426   Yes
# HSBC            Commercial    Public   Implicit   0.14    1.00     277   Yes
# ING              Universal    Public   Implicit   0.74    0.98     144   Yes
# JPMorgan        Commercial    Public   Explicit   0.00    1.00     426   Yes
# Julius Baer        Private    Public         No   0.44    0.95      83   Yes
# LCF                Private   Private         No   0.82    1.00      75    No
# LODH               Private   Private         No   0.44    0.95      83   Yes
# MeesPierson        Private    Public         No   0.74    0.98     144   Yes
# Merrill Lynch   Investment    Public   Implicit   0.00    1.00     426   Yes
# Morgan S        Investment    Public   Explicit   0.14    1.00     277   Yes
# Nordea           Universal    Public   Implicit   0.71    0.95      83    No
# Pictet & Cie       Private   Private         No   0.44    0.95      83   Yes
# RBC              Universal    Public   Explicit   0.23    1.00     149    No
# Rothschild      Investment   Private         No   0.14    1.00     277   Yes
# Santander        Universal    Public   Explicit   0.77    1.00      53    No
# SG               Universal    Public   Explicit   0.82    1.00      75    No
# UBP                Private   Private         No   0.44    0.95      83   Yes
# UBS              Universal    Public   Explicit   0.44    0.95      83   Yes
#
#                Wolfs  Country= NLD  Country= GBR  Country= FRA  Country= SWE  \
# Case
# ABNAmro          No           True         False         False         False
# Barclays        Yes          False          True         False         False
# BNP Paribas      No          False         False          True         False
# Carnegie         No          False         False         False          True
# Citigroup       Yes          False         False         False         False
# Coutts \& Co     No          False          True         False         False
# CS              Yes          False         False         False         False
# Deutsche Bank   Yes          False         False         False         False
# Goldman Sachs   Yes          False         False         False         False
# HSBC            Yes          False          True         False         False
# ING              No           True         False         False         False
# JPMorgan        Yes          False         False         False         False
# Julius Baer      No          False         False         False         False
# LCF              No          False         False          True         False
# LODH             No          False         False         False         False
# MeesPierson      No           True         False         False         False
# Merrill Lynch    No          False         False         False         False
# Morgan S         No          False         False         False         False
# Nordea           No          False         False         False          True
# Pictet & Cie     No          False         False         False         False
# RBC              No          False         False         False         False
# Rothschild       No          False          True         False         False
# Santander       Yes          False         False         False         False
# SG              Yes          False         False          True         False
# UBP              No          False         False         False         False
# UBS             Yes          False         False         False         False
#
#                Country= USA  Country= CHE  Country= GER  Country= CAN  \
# Case
# ABNAmro               False         False         False         False
# Barclays              False         False         False         False
# BNP Paribas           False         False         False         False
# Carnegie              False         False         False         False
# Citigroup              True         False         False         False
# Coutts \& Co          False         False         False         False
# CS                    False          True         False         False
# Deutsche Bank         False         False          True         False
# Goldman Sachs          True         False         False         False
# HSBC                  False         False         False         False
# ING                   False         False         False         False
# JPMorgan               True         False         False         False
# Julius Baer           False          True         False         False
# LCF                   False         False         False         False
# LODH                  False          True         False         False
# MeesPierson           False         False         False         False
# Merrill Lynch          True         False         False         False
# Morgan S               True         False         False         False
# Nordea                False         False         False         False
# Pictet & Cie          False          True         False         False
# RBC                   False         False         False          True
# Rothschild            False         False         False         False
# Santander             False         False         False         False
# SG                    False         False         False         False
# UBP                   False          True         False         False
# UBS                   False          True         False         False
#
#                Country= ESP
# Case
# ABNAmro               False
# Barclays              False
# BNP Paribas           False
# Carnegie              False
# Citigroup             False
# Coutts \& Co          False
# CS                    False
# Deutsche Bank         False
# Goldman Sachs         False
# HSBC                  False
# ING                   False
# JPMorgan              False
# Julius Baer           False
# LCF                   False
# LODH                  False
# MeesPierson           False
# Merrill Lynch         False
# Morgan S              False
# Nordea                False
# Pictet & Cie          False
# RBC                   False
# Rothschild            False
# Santander              True
# SG                    False
# UBP                   False
# UBS                   False

# %%
banking.columns
# Out:
# Index(['Country', 'BankType', 'Owner', 'Code', 'CorpC', 'FinLib', 'RegInt',
#        'BList', 'Wolfs'],
#       dtype='object')

# %%
scaled_banking = banking.copy()
nominal_attributes = ["Country", "BankType", "Owner", "RegInt", "BList", "Wolfs"]
ordinal_attributes = dict()
interordinal_attributes = {"Code": ["No", "Implicit", "Explicit"], "CorpC": None, "FinLib": None}

for nominal_attribute in nominal_attributes:
    scaled_banking = scaling_nominal(scaled_banking, nominal_attribute)
for ordinal_attribute, order in ordinal_attributes.items():
    scaled_banking = scaling_ordinal(scaled_banking, ordinal_attribute, order)
for interordinal_attribute, order in interordinal_attributes.items():
    scaled_banking = scaling_interordinal(scaled_banking, interordinal_attribute, order)

scaled_banking
# Out:
#                Country=NLD  Country=GBR  Country=FRA  Country=SWE  \
# Case
# ABNAmro               True        False        False        False
# Barclays             False         True        False        False
# BNP Paribas          False        False         True        False
# Carnegie             False        False        False         True
# Citigroup            False        False        False        False
# Coutts \& Co         False         True        False        False
# CS                   False        False        False        False
# Deutsche Bank        False        False        False        False
# Goldman Sachs        False        False        False        False
# HSBC                 False         True        False        False
# ING                   True        False        False        False
# JPMorgan             False        False        False        False
# Julius Baer          False        False        False        False
# LCF                  False        False         True        False
# LODH                 False        False        False        False
# MeesPierson           True        False        False        False
# Merrill Lynch        False        False        False        False
# Morgan S             False        False        False        False
# Nordea               False        False        False         True
# Pictet & Cie         False        False        False        False
# RBC                  False        False        False        False
# Rothschild           False         True        False        False
# Santander            False        False        False        False
# SG                   False        False         True        False
# UBP                  False        False        False        False
# UBS                  False        False        False        False
#
#                Country=USA  Country=CHE  Country=GER  Country=CAN  \
# Case
# ABNAmro              False        False        False        False
# Barclays             False        False        False        False
# BNP Paribas          False        False        False        False
# Carnegie             False        False        False        False
# Citigroup             True        False        False        False
# Coutts \& Co         False        False        False        False
# CS                   False         True        False        False
# Deutsche Bank        False        False         True        False
# Goldman Sachs         True        False        False        False
# HSBC                 False        False        False        False
# ING                  False        False        False        False
# JPMorgan              True        False        False        False
# Julius Baer          False         True        False        False
# LCF                  False        False        False        False
# LODH                 False         True        False        False
# MeesPierson          False        False        False        False
# Merrill Lynch         True        False        False        False
# Morgan S              True        False        False        False
# Nordea               False        False        False        False
# Pictet & Cie         False         True        False        False
# RBC                  False        False        False         True
# Rothschild           False        False        False        False
# Santander            False        False        False        False
# SG                   False        False        False        False
# UBP                  False         True        False        False
# UBS                  False         True        False        False
#
#                Country=ESP  BankType=Universal  ...  CorpC<=0.77  CorpC>=0.77  \
# Case                                            ...
# ABNAmro              False                True  ...         True        False
# Barclays             False               False  ...         True        False
# BNP Paribas          False                True  ...        False         True
# Carnegie             False               False  ...         True        False
# Citigroup            False               False  ...         True        False
# Coutts \& Co         False               False  ...         True        False
# CS                   False                True  ...         True        False
# Deutsche Bank        False                True  ...        False         True
# Goldman Sachs        False               False  ...         True        False
# HSBC                 False               False  ...         True        False
# ING                  False                True  ...         True        False
# JPMorgan             False               False  ...         True        False
# Julius Baer          False               False  ...         True        False
# LCF                  False               False  ...        False         True
# LODH                 False               False  ...         True        False
# MeesPierson          False               False  ...         True        False
# Merrill Lynch        False               False  ...         True        False
# Morgan S             False               False  ...         True        False
# Nordea               False                True  ...         True        False
# Pictet & Cie         False               False  ...         True        False
# RBC                  False                True  ...         True        False
# Rothschild           False               False  ...         True        False
# Santander             True                True  ...         True         True
# SG                   False                True  ...        False         True
# UBP                  False               False  ...         True        False
# UBS                  False                True  ...         True        False
#
#                FinLib<=0.98  FinLib>=0.98  FinLib<=1.0  FinLib>=1.0  \
# Case
# ABNAmro                True          True         True        False
# Barclays              False          True         True         True
# BNP Paribas           False          True         True         True
# Carnegie               True         False         True        False
# Citigroup             False          True         True         True
# Coutts \& Co          False          True         True         True
# CS                     True         False         True        False
# Deutsche Bank          True         False         True        False
# Goldman Sachs         False          True         True         True
# HSBC                  False          True         True         True
# ING                    True          True         True        False
# JPMorgan              False          True         True         True
# Julius Baer            True         False         True        False
# LCF                   False          True         True         True
# LODH                   True         False         True        False
# MeesPierson            True          True         True        False
# Merrill Lynch         False          True         True         True
# Morgan S              False          True         True         True
# Nordea                 True         False         True        False
# Pictet & Cie           True         False         True        False
# RBC                   False          True         True         True
# Rothschild            False          True         True         True
# Santander             False          True         True         True
# SG                    False          True         True         True
# UBP                    True         False         True        False
# UBS                    True         False         True        False
#
#                FinLib<=0.95  FinLib>=0.95  FinLib<=0.9  FinLib>=0.9
# Case
# ABNAmro               False          True        False         True
# Barclays              False          True        False         True
# BNP Paribas           False          True        False         True
# Carnegie               True          True        False         True
# Citigroup             False          True        False         True
# Coutts \& Co          False          True        False         True
# CS                     True          True        False         True
# Deutsche Bank          True         False         True         True
# Goldman Sachs         False          True        False         True
# HSBC                  False          True        False         True
# ING                   False          True        False         True
# JPMorgan              False          True        False         True
# Julius Baer            True          True        False         True
# LCF                   False          True        False         True
# LODH                   True          True        False         True
# MeesPierson           False          True        False         True
# Merrill Lynch         False          True        False         True
# Morgan S              False          True        False         True
# Nordea                 True          True        False         True
# Pictet & Cie           True          True        False         True
# RBC                   False          True        False         True
# Rothschild            False          True        False         True
# Santander             False          True        False         True
# SG                    False          True        False         True
# UBP                    True          True        False         True
# UBS                    True          True        False         True
#
# [26 rows x 59 columns]

# %% [markdown]
# # Derivation and closure

# %%
shapes
# Out:
#                       Has 3 Vertices  Has 4 vertices  Has a direct angle  \
# Shape
# Equilateral triangle            True           False               False
# Rectangle triangle              True           False                True
# Rectangle                      False            True                True
# Square                         False            True                True
#
#                       Equilateral
# Shape
# Equilateral triangle         True
# Rectangle triangle          False
# Rectangle                   False
# Square                       True

# %%
def up(ctx: pd.DataFrame, objs: t.Iterable) -> t.List:
    objs = ctx.loc[list(objs)] # get the rows of the objects
    attrs = ctx.columns[objs.all(axis=0)]  # get the column name (attribute) when all the values in the column are True
    return attrs.to_list()

def down(ctx: pd.DataFrame, attrs: t.Iterable) -> t.List:
    attrs = ctx[list(attrs)] # get the columns of the attributes
    objs = ctx.index[attrs.all(axis=1)]  # get the row index (object) when all the values in the row are True
    return objs.to_list()

def updown(ctx: pd.DataFrame, objs: t.Iterable) -> t.Set: return set(down(ctx, up(ctx, objs)))
def downup(ctx: pd.DataFrame, attrs: t.Iterable) -> t.Set: return set(up(ctx, down(ctx, attrs)))

[up(shapes, ["Rectangle", "Rectangle triangle"]),
down(shapes, []),
 updown(shapes, ["Rectangle"]),
updown(shapes, ["Rectangle"]) == updown(shapes, updown(shapes, ["Rectangle"])),
downup(shapes, {"Equilateral"})]
# Out:
# [['Has a direct angle'],
#  ['Equilateral triangle', 'Rectangle triangle', 'Rectangle', 'Square'],
#  {'Rectangle', 'Square'},
#  True,
#  {'Equilateral'}]

# %% [markdown]
# # AllClosure

# %%
def LexicallyLower(intent: t.Set, other: t.Set, attribute_order: t.List, i: int) -> bool:
    if attribute_order[i] not in other.difference(intent):
        return False

    return intent.intersection(attribute_order[:i]) == other.intersection(attribute_order[:i])
    
def NextClosure(ctx: pd.DataFrame, intent: t.Set, attribute_order: t.List) -> t.Set:
    intent = set(intent)
    for i, a in reversed(list(enumerate(attribute_order))): # For all i in M (in reversed order) do
        intent_b = intent.intersection(set(attribute_order[:i]))
        intent_b = downup(ctx, intent_b.union({a}))

        if LexicallyLower(intent, intent_b, attribute_order, i):
            return intent_b
    #return intent # Return A

# %%
def AllClosureYield(ctx: pd.DataFrame, attribute_order: t.List) -> t.Generator[t.Set, None, None]:
    intent = downup(ctx, set())
    bottom = set(up(ctx, set()))
    
    while intent != bottom:
        yield intent
        intent = NextClosure(ctx, intent, attribute_order)
    yield intent
def AllClosure(ctx: pd.DataFrame, attribute_order: t.List) -> t.List[t.Set]:
    return [intent for intent in AllClosureYield(ctx, attribute_order)]

# %%
AllClosure(shapes, shapes.columns.to_list())
# Out:
# [set(),
#  {'Equilateral'},
#  {'Has a direct angle'},
#  {'Has 4 vertices', 'Has a direct angle'},
#  {'Equilateral', 'Has 4 vertices', 'Has a direct angle'},
#  {'Has 3 Vertices'},
#  {'Equilateral', 'Has 3 Vertices'},
#  {'Has 3 Vertices', 'Has a direct angle'},
#  {'Equilateral', 'Has 3 Vertices', 'Has 4 vertices', 'Has a direct angle'}]

# %%
banking_intents = AllClosure(scaled_banking, scaled_banking.columns.to_list())
len(banking_intents)
# Out:
# 550

# %%
import latviz_convert as l
l.df_to_latviz(scaled_banking, "banking.json")

# %%
shapes
# Out:
#                       Has 3 Vertices  Has 4 vertices  Has a direct angle  \
# Shape
# Equilateral triangle            True           False               False
# Rectangle triangle              True           False                True
# Rectangle                      False            True                True
# Square                         False            True                True
#
#                       Equilateral
# Shape
# Equilateral triangle         True
# Rectangle triangle          False
# Rectangle                   False
# Square                       True
